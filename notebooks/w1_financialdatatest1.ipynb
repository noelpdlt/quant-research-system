# %% [markdown]
# ## YFinance Test

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# Retrieving data for a ticker using yfinance
data = yf.download('AAPL', start = '2020-01-01', end = '2025-01-01')
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# 2020-01-02  72.333855  72.394063  71.091161  71.344032  135480400
# 2020-01-03  71.630638  72.389257  71.406666  71.563205  146322800
# 2020-01-06  72.201416  72.239950  70.503554  70.754021  118387200
# 2020-01-07  71.861847  72.466330  71.642689  72.211049  108872000
# 2020-01-08  73.017838  73.318877  71.565621  71.565621  132079200

# %%
# Plot closing price for a ticker against date
data.plot(y = "Close")
plt.title("AAPL Closing Price")
plt.ylabel('Closing Price')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Trial 1

# %%
import sys
from pathlib import Path
import matplotlib.pyplot

sys.path.append(str(Path().resolve().parent))

from src.data import get_data
from src.features import generate_features

# %%
df = get_data('AAPL', '2020-01-01', '2025-01-01')
df = generate_features(df)

df.head(15)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Adj Close      Close       High        Low       Open     Volume  \
# 2020-01-02  72.333855  75.087502  75.150002  73.797501  74.059998  135480400
# 2020-01-03  71.630638  74.357498  75.144997  74.125000  74.287498  146322800
# 2020-01-06  72.201416  74.949997  74.989998  73.187500  73.447502  118387200
# 2020-01-07  71.861847  74.597504  75.224998  74.370003  74.959999  108872000
# 2020-01-08  73.017838  75.797501  76.110001  74.290001  74.290001  132079200
# 2020-01-09  74.568817  77.407501  77.607498  76.550003  76.809998  170108400
# 2020-01-10  74.737366  77.582497  78.167503  77.062500  77.650002  140644800
# 2020-01-13  76.334091  79.239998  79.267502  77.787498  77.910004  121532000
# 2020-01-14  75.303337  78.169998  79.392502  78.042503  79.175003  161954400
# 2020-01-15  74.980614  77.834999  78.875000  77.387497  77.962502  121923600
# 2020-01-16  75.919861  78.809998  78.925003  78.022499  78.397499  108829200
# 2020-01-17  76.760368  79.682503  79.684998  78.750000  79.067497  137816400
# 2020-01-21  76.240181  79.142502  79.754997  79.000000  79.297501  110843200
# 2020-01-22  76.512299  79.425003  79.997498  79.327499  79.644997  101832400
# 2020-01-23  76.880798  79.807503  79.889999  78.912498  79.480003  104472000
#
# Price        returns  volatility  volume_ratio        ma5  ma20  ma50  \
# 2020-01-02       NaN         NaN           NaN        NaN   NaN   NaN
# 2020-01-03 -0.009722         NaN           NaN        NaN   NaN   NaN
# 2020-01-06  0.007968         NaN           NaN        NaN   NaN   NaN
# 2020-01-07 -0.004703         NaN           NaN        NaN   NaN   NaN
# 2020-01-08  0.016086         NaN           NaN  74.958000   NaN   NaN
# 2020-01-09  0.021241         NaN           NaN  75.422000   NaN   NaN
# 2020-01-10  0.002261         NaN           NaN  76.067000   NaN   NaN
# 2020-01-13  0.021364         NaN           NaN  76.925000   NaN   NaN
# 2020-01-14 -0.013503         NaN           NaN  77.639499   NaN   NaN
# 2020-01-15 -0.004286         NaN           NaN  78.046999   NaN   NaN
# 2020-01-16  0.012526         NaN           NaN  78.327498   NaN   NaN
# 2020-01-17  0.011071         NaN           NaN  78.747499   NaN   NaN
# 2020-01-21 -0.006777         NaN           NaN  78.728000   NaN   NaN
# 2020-01-22  0.003570         NaN           NaN  78.979001   NaN   NaN
# 2020-01-23  0.004816         NaN           NaN  79.373502   NaN   NaN
#
# Price       trend_strength  distance_ma20  rsi  momentum  target
# 2020-01-02             NaN            NaN  NaN       NaN       0
# 2020-01-03             NaN            NaN  NaN       NaN       1
# 2020-01-06             NaN            NaN  NaN       NaN       0
# 2020-01-07             NaN            NaN  NaN       NaN       1
# 2020-01-08             NaN            NaN  NaN       NaN       1
# 2020-01-09             NaN            NaN  NaN       NaN       1
# 2020-01-10             NaN            NaN  NaN       NaN       1
# 2020-01-13             NaN            NaN  NaN       NaN       0
# 2020-01-14             NaN            NaN  NaN       NaN       0
# 2020-01-15             NaN            NaN  NaN       NaN       1
# 2020-01-16             NaN            NaN  NaN       NaN       1
# 2020-01-17             NaN            NaN  NaN       NaN       0
# 2020-01-21             NaN            NaN  NaN       NaN       1
# 2020-01-22             NaN            NaN  NaN       NaN       1
# 2020-01-23             NaN            NaN  NaN       NaN       0

# %%
#Plotting Price against Moving Average
plt.plot(df.index, df[('Close')], label='Price')
plt.plot(df.index, df['ma20'], label='MA20')

plt.title('Price vs. Moving Average')
plt.xlabel('Date')
plt.legend()
plt.show()
