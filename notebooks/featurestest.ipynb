# %%
import sys
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

sys.path.append(str(Path().resolve().parent))

from src.data import get_data
from src.features import compute_returns, moving_average, rolling_volatility, volume_ratio, trend_strength
from src.backtest import backtest_mr, sharpe_ratio, volatility, max_drawdown, backtest_mom
from src.strategy import mean_reversion_strategy, momentum_strategy
from src.visualization import plot_performance

# %% [markdown]
# ## Rolling Volatility

# %%
df = get_data('AAPL', '2021-01-01', '2026-01-01')
df = compute_returns(df)
df = rolling_volatility(df)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index, df["volatility"])

plt.xlabel("Date")
plt.ylabel("Rolling Volatility")
plt.legend()
plt.show()
# Out:
# /var/folders/f5/793n94tx3jj8c_rrt1drx2g40000gn/T/ipykernel_96231/1884540131.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Volume Ratio

# %%
df = volume_ratio(df)

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index, df["volume_ratio"])

plt.xlabel("Date")
plt.ylabel("Volume Ratio")
plt.legend()
plt.show()
# Out:
# /var/folders/f5/793n94tx3jj8c_rrt1drx2g40000gn/T/ipykernel_96231/2479799169.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Trend Strength

# %%
df = trend_strength(df)

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index, df["trend_strength"])

plt.xlabel("Date")
plt.ylabel("Trend Strength")
plt.legend()
plt.show()
# Out:
# /var/folders/f5/793n94tx3jj8c_rrt1drx2g40000gn/T/ipykernel_96231/35991281.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
